# %%
# !pip install sqlalchemy

# %%
# !pip install pyodbc

# %%
# !python -m pip install "pymongo[srv]"

# %%
# !pip install "pymongo[srv]"

# %%
import sqlalchemy as db
from sqlalchemy import text
import pandas as pd
from pymongo import MongoClient

# %%
# !pip install mysqlclient

# %%
engine = db.create_engine("mysql://root:root@127.0.0.1:3310/retail_db")
conn=engine.connect()

# %%
df=pd.read_sql_query('SELECT * FROM categories',con=conn)
df
# Out:
#     category_id  category_department_id         category_name
# 0             1                       2              Football
# 1             2                       2                Soccer
# 2             3                       2   Baseball & Softball
# 3             4                       2            Basketball
# 4             5                       2              Lacrosse
# 5             6                       2      Tennis & Racquet
# 6             7                       2                Hockey
# 7             8                       2           More Sports
# 8             9                       3      Cardio Equipment
# 9            10                       3     Strength Training
# 10           11                       3   Fitness Accessories
# 11           12                       3          Boxing & MMA
# 12           13                       3           Electronics
# 13           14                       3        Yoga & Pilates
# ...

# %%
df=pd.read_sql_query('SELECT * FROM customers',con=conn)
df
# Out:
#        customer_id customer_fname customer_lname customer_email  \
# 0                1        Richard      Hernandez      XXXXXXXXX
# 1                2           Mary        Barrett      XXXXXXXXX
# 2                3            Ann          Smith      XXXXXXXXX
# 3                4           Mary          Jones      XXXXXXXXX
# 4                5         Robert         Hudson      XXXXXXXXX
# ...            ...            ...            ...            ...
# 12430        12431           Mary           Rios      XXXXXXXXX
# 12431        12432         Angela          Smith      XXXXXXXXX
# 12432        12433       Benjamin         Garcia      XXXXXXXXX
# 12433        12434           Mary          Mills      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
#
#       customer_password             customer_street customer_city  \
# 0             XXXXXXXXX          6303 Heather Plaza   Brownsville
# ...

# %%
df_customers=pd.read_sql_query('SELECT * FROM categories',con=conn)
df_customers.tail()
# Out:
#     category_id  category_department_id         category_name
# 53           54                       8                   MLS
# 54           55                       8  International Soccer
# 55           56                       8        World Cup Shop
# 56           57                       8           MLB Players
# 57           58                       8           NFL Players

# %%
#conexion a mongo db
CONNECTION_STRING = "mongodb+srv://datayzuguisystem:p82zthxxoW5YYj6sW@cluster0.feygbkw.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
client=MongoClient(CONNECTION_STRING)

# %%
dbname=client["retail_db"]

# %%
df = df_customers.copy()
df_to_dict=df.to_dict("records")
dbname["customers"].insert_many(df_to_dict)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[57], line 3
#       1 df = df_customers.copy()
#       2 df_to_dict=df.to_dict("records")
# ----> 3 dbname["customers"].insert_many(df_to_dict)
#
# File ~/.python/current/lib/python3.10/site-packages/pymongo/_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File ~/.python/current/lib/python3.10/site-packages/pymongo/collection.py:742, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     740 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     741 blk.ops = list(gen())
# --> 742 blk.execute(write_concern, session, _Op.INSERT)
# ...

# %%
collection_curtomers = dbname["customers"]
customers = collection_curtomers.find({})
customers

# %%
df_customers_mongo = pd.DataFrame(customers)
df_customers_mongo
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df_customers_mongo = pd.DataFrame(customers)
#       2 df_customers_mongo
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:843, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     841         data = np.asarray(data)
#     842     else:
# --> 843         data = list(data)
#     844 if len(data) > 0:
#     845     if is_dataclass(data[0]):
#
# File ~/.python/current/lib/python3.10/site-packages/pymongo/cursor.py:1243, in Cursor.next(self)
#    1241 if self.__empty:
#    1242     raise StopIteration
# -> 1243 if len(self.__data) or self._refresh():
#    1244     return self.__data.popleft()
#    1245 else:
#
# File ~/.python/current/lib/python3.10/site-packages/pymongo/cursor.py:1160, in Cursor._refresh(self)
#    1138         raise InvalidOperation(
# ...
