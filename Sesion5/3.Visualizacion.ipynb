# %%
# !pip install sweetviz #para data numerica
# Out:
# Requirement already satisfied: sweetviz in /usr/local/python/3.10.13/lib/python3.10/site-packages (2.3.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /home/codespace/.local/lib/python3.10/site-packages (from sweetviz) (2.2.2)
# Requirement already satisfied: numpy>=1.16.0 in /home/codespace/.local/lib/python3.10/site-packages (from sweetviz) (1.26.4)
# Requirement already satisfied: matplotlib>=3.1.3 in /home/codespace/.local/lib/python3.10/site-packages (from sweetviz) (3.9.0)
# Requirement already satisfied: tqdm>=4.43.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from sweetviz) (4.66.4)
# Requirement already satisfied: scipy>=1.3.2 in /home/codespace/.local/lib/python3.10/site-packages (from sweetviz) (1.13.1)
# Requirement already satisfied: jinja2>=2.11.1 in /home/codespace/.local/lib/python3.10/site-packages (from sweetviz) (3.1.4)
# Requirement already satisfied: importlib-resources>=1.2.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from sweetviz) (6.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2>=2.11.1->sweetviz) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (24.0)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.10/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pandas as pd
import sweetviz as sv

# %%
df = pd.read_csv('./data/Test.csv')
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
#no correr solo caminar
report = sv.analyze(df)
report.show_html("report_sv.html")

# %%
! pip install dtale
# Out:
# Requirement already satisfied: dtale in /usr/local/python/3.10.13/lib/python3.10/site-packages (3.12.0)
# Requirement already satisfied: dash-colorscales in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (0.0.4)
# Requirement already satisfied: dash-daq in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (0.5.0)
# Requirement already satisfied: Flask-Compress in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (1.15)
# Requirement already satisfied: future>=0.14.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (1.0.0)
# Requirement already satisfied: kaleido in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (0.2.1)
# Requirement already satisfied: missingno in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (0.5.2)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.10/site-packages (from dtale) (2.2.2)
# Requirement already satisfied: squarify in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (0.4.3)
# Requirement already satisfied: strsimpy in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (0.2.1)
# Requirement already satisfied: six in /home/codespace/.local/lib/python3.10/site-packages (from dtale) (1.16.0)
# Requirement already satisfied: xlrd in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (2.0.1)
# Requirement already satisfied: beautifulsoup4!=4.13.0b2 in /home/codespace/.local/lib/python3.10/site-packages (from dtale) (4.12.3)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.10/site-packages (from dtale) (2024.2.2)
# Requirement already satisfied: flask-ngrok in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (0.0.25)
# Requirement already satisfied: lz4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (4.3.3)
# Requirement already satisfied: cycler in /home/codespace/.local/lib/python3.10/site-packages (from dtale) (0.12.1)
# Requirement already satisfied: dash-bootstrap-components<=1.3.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (1.3.1)
# Requirement already satisfied: dash in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (2.17.1)
# Requirement already satisfied: seaborn in /home/codespace/.local/lib/python3.10/site-packages (from dtale) (0.13.2)
# Requirement already satisfied: werkzeug in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (3.0.3)
# Requirement already satisfied: scikit-learn in /home/codespace/.local/lib/python3.10/site-packages (from dtale) (1.5.0)
# Requirement already satisfied: statsmodels in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (0.14.2)
# Requirement already satisfied: networkx in /home/codespace/.local/lib/python3.10/site-packages (from dtale) (3.3)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (from dtale) (1.26.4)
# Requirement already satisfied: openpyxl!=3.2.0b1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (3.1.4)
# Requirement already satisfied: xarray in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (2024.6.0)
# Requirement already satisfied: et-xmlfile in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (1.1.0)
# Requirement already satisfied: plotly in /home/codespace/.local/lib/python3.10/site-packages (from dtale) (5.22.0)
# Requirement already satisfied: Flask<2.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (2.2.5)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.10/site-packages (from dtale) (2.32.3)
# Requirement already satisfied: itsdangerous in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dtale) (2.2.0)
# Requirement already satisfied: contourpy in /home/codespace/.local/lib/python3.10/site-packages (from dtale) (1.2.1)
# Requirement already satisfied: matplotlib in /home/codespace/.local/lib/python3.10/site-packages (from dtale) (3.9.0)
# Requirement already satisfied: scipy!=1.12.0rc1 in /home/codespace/.local/lib/python3.10/site-packages (from dtale) (1.13.1)
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/lib/python3.10/site-packages (from beautifulsoup4!=4.13.0b2->dtale) (2.5)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dash->dtale) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dash->dtale) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dash->dtale) (5.0.0)
# Requirement already satisfied: importlib-metadata in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dash->dtale) (7.2.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from dash->dtale) (4.12.0)
# Requirement already satisfied: retrying in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dash->dtale) (1.3.4)
# Requirement already satisfied: nest-asyncio in /home/codespace/.local/lib/python3.10/site-packages (from dash->dtale) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dash->dtale) (68.2.2)
# Requirement already satisfied: Jinja2>=3.0 in /home/codespace/.local/lib/python3.10/site-packages (from Flask<2.3->dtale) (3.1.4)
# Requirement already satisfied: click>=8.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from Flask<2.3->dtale) (8.1.7)
# Requirement already satisfied: tenacity>=6.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from plotly->dtale) (8.3.0)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.10/site-packages (from plotly->dtale) (24.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from werkzeug->dtale) (2.1.5)
# Requirement already satisfied: brotli in /usr/local/python/3.10.13/lib/python3.10/site-packages (from Flask-Compress->dtale) (1.1.0)
# Requirement already satisfied: zstandard in /usr/local/python/3.10.13/lib/python3.10/site-packages (from Flask-Compress->dtale) (0.22.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->dtale) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->dtale) (1.4.5)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->dtale) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->dtale) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->dtale) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas->dtale) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.10/site-packages (from pandas->dtale) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests->dtale) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests->dtale) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests->dtale) (2.0.7)
# Requirement already satisfied: joblib>=1.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn->dtale) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn->dtale) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from statsmodels->dtale) (0.5.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from importlib-metadata->dash->dtale) (3.19.2)
#
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pandas as pd
import dtale

# %%
# Cargar un DataFrame de ejemplo
df = pd.read_csv('./data/Test.csv')
 
# Iniciar D-Tale
d = dtale.show(df)
d.open_browser()
